# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_excel('Election_Data.xlsx')

# %%
df.head()
# Out:
#    Unnamed: 0    vote  age  economic.cond.national  economic.cond.household  \
# 0           1  Labour   43                       3                        3
# 1           2  Labour   36                       4                        4
# 2           3  Labour   35                       4                        4
# 3           4  Labour   24                       4                        2
# 4           5  Labour   41                       2                        2
#
#    Blair  Hague  Europe  political.knowledge  gender
# 0      4      1       2                    2  female
# 1      4      4       5                    2    male
# 2      5      2       3                    2    male
# 3      2      1       4                    0  female
# 4      1      1       6                    2    male

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1525 entries, 0 to 1524
# Data columns (total 10 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unnamed: 0               1525 non-null   int64
#  1   vote                     1525 non-null   object
#  2   age                      1525 non-null   int64
#  3   economic.cond.national   1525 non-null   int64
#  4   economic.cond.household  1525 non-null   int64
#  5   Blair                    1525 non-null   int64
#  6   Hague                    1525 non-null   int64
#  7   Europe                   1525 non-null   int64
#  8   political.knowledge      1525 non-null   int64
#  9   gender                   1525 non-null   object
# dtypes: int64(8), object(2)
# memory usage: 119.3+ KB

# %%
df.duplicated().sum() #We will  now check if there are any duplicate entries in the dataset.
# Out:
# 0

# %%
df.drop('Unnamed: 0', inplace = True, axis = 1)

# %%
df.isnull().sum() #We will now check the count of missing values.
# Out:
# vote                       0
# age                        0
# economic.cond.national     0
# economic.cond.household    0
# Blair                      0
# Hague                      0
# Europe                     0
# political.knowledge        0
# gender                     0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1525 entries, 0 to 1524
# Data columns (total 9 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   vote                     1525 non-null   object
#  1   age                      1525 non-null   int64
#  2   economic.cond.national   1525 non-null   int64
#  3   economic.cond.household  1525 non-null   int64
#  4   Blair                    1525 non-null   int64
#  5   Hague                    1525 non-null   int64
#  6   Europe                   1525 non-null   int64
#  7   political.knowledge      1525 non-null   int64
#  8   gender                   1525 non-null   object
# dtypes: int64(7), object(2)
# memory usage: 107.4+ KB

# %%
df.describe().T
# Out:
#                           count       mean        std   min   25%   50%   75%  \
# age                      1525.0  54.182295  15.711209  24.0  41.0  53.0  67.0
# economic.cond.national   1525.0   3.245902   0.880969   1.0   3.0   3.0   4.0
# economic.cond.household  1525.0   3.140328   0.929951   1.0   3.0   3.0   4.0
# Blair                    1525.0   3.334426   1.174824   1.0   2.0   4.0   4.0
# Hague                    1525.0   2.746885   1.230703   1.0   2.0   2.0   4.0
# Europe                   1525.0   6.728525   3.297538   1.0   4.0   6.0  10.0
# political.knowledge      1525.0   1.542295   1.083315   0.0   0.0   2.0   2.0
#
#                           max
# age                      93.0
# economic.cond.national    5.0
# economic.cond.household   5.0
# Blair                     5.0
# Hague                     5.0
# Europe                   11.0
# political.knowledge       3.0

# %%
df.skew()
# Out:
# C:\Users\NIKHIL~1\AppData\Local\Temp/ipykernel_18672/1665899112.py:1: FutureWarning: The default value of numeric_only in DataFrame.skew is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.skew()
# age                        0.144621
# economic.cond.national    -0.240453
# economic.cond.household   -0.149552
# Blair                     -0.535419
# Hague                      0.152100
# Europe                    -0.135947
# political.knowledge       -0.426838
# dtype: float64

# %%
df["gender"].value_counts()
# Out:
# female    812
# male      713
# Name: gender, dtype: int64

# %%
df["vote"].value_counts()
# Out:
# Labour          1063
# Conservative     462
# Name: vote, dtype: int64

# %%
df.columns
# Out:
# Index(['vote', 'age', 'economic.cond.national', 'economic.cond.household',
#        'Blair', 'Hague', 'Europe', 'political.knowledge', 'gender'],
#       dtype='object')

# %%
#Univariate and Bivariate Analysis

# %%
mycolors = ['#0E39A9', '#1974D2', '#000000', '#452B4E', '#856FAB', '#DD66AF', '#FFDE59', '#F5EFFF']
#royBlue, slightblue, black, darkpurp, stilldarkpurp, pink, yellow, white

confusion = ['#dd66af', '#ffde59', '#856fab', '#fcfaff']

# %%
sns.set_palette(mycolors)

# %%
royal_blue = sns.color_palette()[0]
slight_blue = sns.color_palette()[1]
black = sns.color_palette()[2]
dark_purple = sns.color_palette()[3]
still_dark_purple = sns.color_palette()[4]
pink = sns.color_palette()[5]
yellow = sns.color_palette()[6]
white = sns.color_palette()[7]

# %%
selected_columns = df[['age', 'economic.cond.national', 'economic.cond.household', 'Blair', 'Hague', 'Europe', 'political.knowledge']]

# %%
for col in selected_columns.columns:
    plt.figure(figsize=(14,11))
    sns.distplot(df[col], kde=True)
    
    plt.show()
# Out:
# C:\Users\NikhilSingh\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\NikhilSingh\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
for cols in selected_columns.columns:
    plt.figure(figsize=(14,11))
    sns.histplot(df[cols], kde=True)
    plt.show()

# %%
for cols in selected_columns.columns:
    plt.figure(figsize=(14,11))
    sns.boxplot(df[cols], palette=[still_dark_purple], showmeans = True)
    plt.show()
# Out:
# C:\Users\NikhilSingh\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\NikhilSingh\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\NikhilSingh\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %%
for cols in df.columns:
    plt.figure(figsize=(14,11))
    sns.countplot(df[cols])
    plt.show()
# Out:
# C:\Users\NikhilSingh\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\NikhilSingh\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\NikhilSingh\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %%
plt.figure(figsize=(14,11))
sns.pairplot(df, corner=True)

# %%
for cols in selected_columns.columns:
    plt.figure(figsize=(14,11))
    sns.boxplot(df[cols],df["age"], showmeans = True)
    plt.show()
# Out:
# C:\Users\NikhilSingh\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\NikhilSingh\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\NikhilSingh\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
# ...

# %%
sns.histplot(df['age'], kde = True)
# Out:
# <AxesSubplot:xlabel='age', ylabel='Count'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1525 entries, 0 to 1524
# Data columns (total 9 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   vote                     1525 non-null   object
#  1   age                      1525 non-null   int64
#  2   economic.cond.national   1525 non-null   int64
#  3   economic.cond.household  1525 non-null   int64
#  4   Blair                    1525 non-null   int64
#  5   Hague                    1525 non-null   int64
#  6   Europe                   1525 non-null   int64
#  7   political.knowledge      1525 non-null   int64
#  8   gender                   1525 non-null   object
# dtypes: int64(7), object(2)
# memory usage: 107.4+ KB

# %%
sns.set_palette(mycolors)

# %%
sns.boxplot(df['gender'], df['age'])
# Out:
# C:\Users\NikhilSingh\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='gender', ylabel='age'>

# %%
df.corr()
# Out:
# C:\Users\NIKHIL~1\AppData\Local\Temp/ipykernel_18672/1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                               age  economic.cond.national  \
# age                      1.000000                0.018567
# economic.cond.national   0.018567                1.000000
# economic.cond.household -0.041587                0.346303
# Blair                    0.030218                0.326878
# Hague                    0.034626               -0.199766
# Europe                   0.068880               -0.209429
# political.knowledge     -0.048490               -0.023624
#
#                          economic.cond.household     Blair     Hague  \
# age                                    -0.041587  0.030218  0.034626
# ...

# %%
plt.figure(figsize=(14,11))
sns.heatmap(df.corr(), annot = True, cmap=mycolors, linecolor=yellow, robust=False)
# Out:
# C:\Users\NIKHIL~1\AppData\Local\Temp/ipykernel_18672/667857204.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), annot = True, cmap=mycolors, linecolor=yellow, robust=False)
# <AxesSubplot:>

# %%
#encoding Part 3

# %%
df
# Out:
#               vote  age  economic.cond.national  economic.cond.household  \
# 0           Labour   43                       3                        3
# 1           Labour   36                       4                        4
# 2           Labour   35                       4                        4
# 3           Labour   24                       4                        2
# 4           Labour   41                       2                        2
# ...            ...  ...                     ...                      ...
# 1520  Conservative   67                       5                        3
# 1521  Conservative   73                       2                        2
# 1522        Labour   37                       3                        3
# 1523  Conservative   61                       3                        3
# 1524  Conservative   74                       2                        3
#
#       Blair  Hague  Europe  political.knowledge  gender
# ...

# %%
df_encoded = pd.get_dummies(df, columns = ['vote', 'gender'], drop_first = True) 
df_encoded
# Out:
#       age  economic.cond.national  economic.cond.household  Blair  Hague  \
# 0      43                       3                        3      4      1
# 1      36                       4                        4      4      4
# 2      35                       4                        4      5      2
# 3      24                       4                        2      2      1
# 4      41                       2                        2      1      1
# ...   ...                     ...                      ...    ...    ...
# 1520   67                       5                        3      2      4
# 1521   73                       2                        2      4      4
# 1522   37                       3                        3      5      4
# 1523   61                       3                        3      1      4
# 1524   74                       2                        3      2      4
#
#       Europe  political.knowledge  vote_Labour  gender_male
# ...

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
scaled = scaler.fit_transform(df_encoded) 
scaled
# Out:
# array([[0.27536232, 0.5       , 0.5       , ..., 0.66666667, 1.        ,
#         0.        ],
#        [0.17391304, 0.75      , 0.75      , ..., 0.66666667, 1.        ,
#         1.        ],
#        [0.15942029, 0.75      , 0.75      , ..., 0.66666667, 1.        ,
#         1.        ],
#        ...,
#        [0.1884058 , 0.5       , 0.5       , ..., 0.66666667, 1.        ,
#         1.        ],
#        [0.53623188, 0.5       , 0.5       , ..., 0.66666667, 0.        ,
#         1.        ],
#        [0.72463768, 0.25      , 0.5       , ..., 0.        , 0.        ,
#         0.        ]])

# %%
scaled_df = pd.DataFrame(scaled, columns=df_encoded.columns)

# %%
scaled_df
# Out:
#            age  economic.cond.national  economic.cond.household  Blair  Hague  \
# 0     0.275362                    0.50                     0.50   0.75   0.00
# 1     0.173913                    0.75                     0.75   0.75   0.75
# 2     0.159420                    0.75                     0.75   1.00   0.25
# 3     0.000000                    0.75                     0.25   0.25   0.00
# 4     0.246377                    0.25                     0.25   0.00   0.00
# ...        ...                     ...                      ...    ...    ...
# 1520  0.623188                    1.00                     0.50   0.25   0.75
# 1521  0.710145                    0.25                     0.25   0.75   0.75
# 1522  0.188406                    0.50                     0.50   1.00   0.75
# 1523  0.536232                    0.50                     0.50   0.00   0.75
# 1524  0.724638                    0.25                     0.50   0.25   0.75
#
# ...

# %%
scaled_df.describe()
# Out:
#                age  economic.cond.national  economic.cond.household  \
# count  1525.000000             1525.000000              1525.000000
# mean      0.437425                0.561475                 0.535082
# std       0.227699                0.220242                 0.232488
# min       0.000000                0.000000                 0.000000
# 25%       0.246377                0.500000                 0.500000
# 50%       0.420290                0.500000                 0.500000
# 75%       0.623188                0.750000                 0.750000
# max       1.000000                1.000000                 1.000000
#
#              Blair        Hague       Europe  political.knowledge  \
# count  1525.000000  1525.000000  1525.000000          1525.000000
# mean      0.583607     0.436721     0.572852             0.514098
# std       0.293706     0.307676     0.329754             0.361105
# min       0.000000     0.000000     0.000000             0.000000
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
x = scaled_df.drop("vote_Labour",axis = 1)
y = scaled_df['vote_Labour']

# %%
y.shape
# Out:
# (1525,)

# %%
x.shape
# Out:
# (1525, 8)

# %%
x_train,x_test , y_train, y_test = train_test_split(x,y,test_size = .30 ,random_state = 1)

# %%
print('x_train', x_train.shape)

print('y_train', y_train.shape)

print('x_test', x_test.shape)

print('y_test', y_test.shape)
# Out:
# x_train (1067, 8)
# y_train (1067,)
# x_test (458, 8)
# y_test (458,)

# %%
#Logistic Regression and LDA

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression(tol=0.0001,max_iter=2000,random_state= 0)

# %%
lr.fit(x_train,y_train)
# Out:
# LogisticRegression(max_iter=2000, random_state=0)

# %%
y_train_predict=lr.predict(x_train)

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
print(classification_report(y_train ,y_train_predict))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.77      0.68      0.72       332
#          1.0       0.86      0.91      0.89       735
#
#     accuracy                           0.84      1067
#    macro avg       0.82      0.79      0.80      1067
# weighted avg       0.83      0.84      0.83      1067

# %%
print(sns.heatmap(confusion_matrix(y_train,y_train_predict),annot=True, fmt="d", cmap=mycolors))
plt.show()
confusion_matrix(y_train,y_train_predict)
# Out:
# AxesSubplot(0.125,0.125;0.62x0.755)
# array([[226, 106],
#        [ 67, 668]], dtype=int64)

# %%
print(classification_report(y_test,lr.predict(x_test)))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.70      0.65      0.67       130
#          1.0       0.86      0.89      0.88       328
#
#     accuracy                           0.82       458
#    macro avg       0.78      0.77      0.77       458
# weighted avg       0.82      0.82      0.82       458

# %%
print(sns.heatmap(confusion_matrix(y_test,lr.predict(x_test)),annot=True, fmt="d", cmap=mycolors))
confusion_matrix(y_test,lr.predict(x_test))
# Out:
# AxesSubplot(0.125,0.125;0.62x0.755)
# array([[ 84,  46],
#        [ 36, 292]], dtype=int64)

# %%
from sklearn.metrics import mean_squared_error
print('Error for Train Data:', mean_squared_error(y_train_predict, y_train))
print('Error for Test Data:', mean_squared_error(lr.predict(x_test), y_test))
# Out:
# Error for Train Data: 0.16213683223992503
# Error for Test Data: 0.17903930131004367

# %%
print('Error for Test Data:', mean_squared_error(lr.predict(x_test), y_test))
# Out:
# Error for Test Data: 0.17903930131004367

# %%
from sklearn.metrics import roc_auc_score,roc_curve

# %%
probs = lr.predict_proba(x_train)
probs = probs[:, 1]
from sklearn.metrics import roc_auc_score
auc = roc_auc_score(y_train, probs)
print('AUC: %.3f' % auc)
from sklearn.metrics import roc_curve
fpr, tpr, thresholds = roc_curve(y_train, probs)
plt.plot([0, 1], [0, 1], linestyle='solid')
plt.plot(fpr, tpr, marker='.')
plt.show()
# Out:
# AUC: 0.890

# %%
probs = lr.predict_proba(x_test)

probs = probs[:, 1]
from sklearn.metrics import roc_auc_score
auc = roc_auc_score(y_test, probs)
print('AUC: %.3f' % auc)
from sklearn.metrics import roc_curve
fpr, tpr, thresholds = roc_curve(y_test, probs)
plt.plot([0, 1], [0, 1], linestyle='solid')
plt.plot(fpr, tpr, marker='.')
plt.show()
# Out:
# AUC: 0.883

# %%
#lda

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

# %%
lda = LinearDiscriminantAnalysis()

# %%
lda = lda.fit(x_train,y_train)

# %%
sns.color_palette(mycolors)
sns.heatmap(confusion_matrix(lda.predict(x_train),y_train), cmap = mycolors, annot = True, fmt="d")
# Out:
# <AxesSubplot:>

# %%
print(classification_report(lda.predict(x_train),y_train))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.70      0.76      0.73       308
#          1.0       0.90      0.87      0.88       759
#
#     accuracy                           0.84      1067
#    macro avg       0.80      0.81      0.81      1067
# weighted avg       0.84      0.84      0.84      1067

# %%
print(confusion_matrix(lda.predict(x_test),y_test))
# Out:
# [[ 86  39]
#  [ 44 289]]

# %%
sns.heatmap(confusion_matrix(lda.predict(x_test),y_test), cmap = mycolors, annot = True, fmt="d")
# Out:
# <AxesSubplot:>

# %%
print(classification_report(lda.predict(x_test),y_test))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.66      0.69      0.67       125
#          1.0       0.88      0.87      0.87       333
#
#     accuracy                           0.82       458
#    macro avg       0.77      0.78      0.77       458
# weighted avg       0.82      0.82      0.82       458

# %%
probs = lda.predict_proba(x_train)
probs = probs[:, 1]
from sklearn.metrics import roc_auc_score
auc = roc_auc_score(y_train, probs)
print('AUC: %.3f' % auc)
from sklearn.metrics import roc_curve
fpr, tpr, thresholds = roc_curve(y_train, probs)
plt.plot([0, 1], [0, 1], linestyle='solid')
plt.plot(fpr, tpr, marker='.')
# Out:
# AUC: 0.889

# %%
probs = lda.predict_proba(x_test)
probs = probs[:, 1]
from sklearn.metrics import roc_auc_score
auc = roc_auc_score(y_test, probs)
print('AUC: %.3f' % auc)
from sklearn.metrics import roc_curve
fpr, tpr, thresholds = roc_curve(y_test, probs)
plt.plot([0, 1], [0, 1], linestyle='solid')
plt.plot(fpr, tpr, marker='.')
plt.show()
# Out:
# AUC: 0.884

# %%
#KNN Model and Naïve Bayes

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn = KNeighborsClassifier(n_neighbors = 5)

# %%
knn = knn.fit(x_train,y_train)

# %%
pred_label= knn.predict(x_test)
print('Score for Test Data: ', knn.score(x_test,y_test))
print('Score for Train Data: ', knn.score(x_train,y_train))
# Out:
# Score for Test Data:  0.8253275109170306
# Score for Train Data:  0.865979381443299

# %%
print(confusion_matrix(knn.predict(x_train),y_train))
# Out:
# [[252  63]
#  [ 80 672]]

# %%
sns.heatmap(confusion_matrix(knn.predict(x_train),y_train), cmap = mycolors, annot = True, fmt="d")
# Out:
# <AxesSubplot:>

# %%
print(classification_report(knn.predict(x_train),y_train))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.76      0.80      0.78       315
#          1.0       0.91      0.89      0.90       752
#
#     accuracy                           0.87      1067
#    macro avg       0.84      0.85      0.84      1067
# weighted avg       0.87      0.87      0.87      1067

# %%
probs = knn.predict_proba(x_train)
probs = probs[:, 1]
from sklearn.metrics import roc_auc_score
auc = roc_auc_score(y_train, probs)
print('AUC: %.3f' % auc)
from sklearn.metrics import roc_curve
fpr, tpr, thresholds = roc_curve(y_train, probs)
plt.plot([0, 1], [0, 1], linestyle='solid')
plt.plot(fpr, tpr, marker='.')
# Out:
# AUC: 0.935

# %%
probs = knn.predict_proba(x_test)
probs = probs[:, 1]
from sklearn.metrics import roc_auc_score
auc = roc_auc_score(y_test, probs)
print('AUC: %.3f' % auc)
from sklearn.metrics import roc_curve
fpr, tpr, thresholds = roc_curve(y_test, probs)
plt.plot([0, 1], [0, 1], linestyle='solid')
plt.plot(fpr, tpr, marker='.')
plt.show()
# Out:
# AUC: 0.865

# %%
knn.score(x_train,y_train)
# Out:
# 0.865979381443299

# %%
sns.heatmap(confusion_matrix(knn.predict(x_test),y_test), cmap = mycolors, annot = True, fmt="d")
# Out:
# <AxesSubplot:>

# %%
print(confusion_matrix(knn.predict(x_test),y_test))
# Out:
# [[ 95  45]
#  [ 35 283]]

# %%
print(classification_report(knn.predict(x_test),y_test))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.73      0.68      0.70       140
#          1.0       0.86      0.89      0.88       318
#
#     accuracy                           0.83       458
#    macro avg       0.80      0.78      0.79       458
# weighted avg       0.82      0.83      0.82       458

# %%
#naive

# %%
from sklearn.naive_bayes import GaussianNB

# %%
nb=GaussianNB()

# %%
nb= nb.fit(x_train, y_train)

# %%
confusion_matrix(nb.predict(x_train),y_train)
# Out:
# array([[240,  86],
#        [ 92, 649]], dtype=int64)

# %%
sns.heatmap(confusion_matrix(nb.predict(x_train),y_train), cmap = mycolors, annot = True, fmt="d")
# Out:
# <AxesSubplot:>

# %%
print(classification_report(nb.predict(x_train),y_train))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.72      0.74      0.73       326
#          1.0       0.88      0.88      0.88       741
#
#     accuracy                           0.83      1067
#    macro avg       0.80      0.81      0.80      1067
# weighted avg       0.83      0.83      0.83      1067

# %%
confusion_matrix(nb.predict(x_test),y_test)
# Out:
# array([[ 94,  44],
#        [ 36, 284]], dtype=int64)

# %%
sns.heatmap(confusion_matrix(nb.predict(x_test),y_test), cmap = mycolors, annot = True, fmt="d")
# Out:
# <AxesSubplot:>

# %%
print(classification_report(nb.predict(x_test),y_test))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.72      0.68      0.70       138
#          1.0       0.87      0.89      0.88       320
#
#     accuracy                           0.83       458
#    macro avg       0.79      0.78      0.79       458
# weighted avg       0.82      0.83      0.82       458

# %%
probs = nb.predict_proba(x_train)
probs = probs[:, 1]
from sklearn.metrics import roc_auc_score
auc = roc_auc_score(y_train, probs)
print('AUC: %.3f' % auc)
from sklearn.metrics import roc_curve
fpr, tpr, thresholds = roc_curve(y_train, probs)
plt.plot([0, 1], [0, 1], linestyle='solid')
plt.plot(fpr, tpr, marker='.')
# Out:
# AUC: 0.886

# %%
probs = nb.predict_proba(x_test)
probs = probs[:, 1]
from sklearn.metrics import roc_auc_score
auc = roc_auc_score(y_test, probs)
print('AUC: %.3f' % auc)
from sklearn.metrics import roc_curve
fpr, tpr, thresholds = roc_curve(y_test, probs)
plt.plot([0, 1], [0, 1], linestyle='solid')
plt.plot(fpr, tpr, marker='.')
plt.show()
# Out:
# AUC: 0.885

# %%
#Model Tuning, Bagging

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import AdaBoostClassifier

# %%
param_grid = {
    'n_estimators' : [100,500,1000],
    'learning_rate' : [0.1,0.01,0.001],
    'algorithm' : ['SAMME', 'SAMME.R']
}

# %%
ADB_model=AdaBoostClassifier()

# %%
grid_search=GridSearchCV(estimator=ADB_model,param_grid=param_grid)

# %%
grid_search.fit(x_train,y_train)
# Out:
# GridSearchCV(estimator=AdaBoostClassifier(),
#              param_grid={'algorithm': ['SAMME', 'SAMME.R'],
#                          'learning_rate': [0.1, 0.01, 0.001],
#                          'n_estimators': [100, 500, 1000]})

# %%
ADB_model=grid_search.best_estimator_

# %%
ADB_model.fit(x_train,y_train)
# Out:
# AdaBoostClassifier(algorithm='SAMME', learning_rate=0.1, n_estimators=1000)

# %%
y_train_predict = ADB_model.predict(x_train)
model_score = ADB_model.score(x_train, y_train)
print('The ADB Model Score for Train Data is: ', model_score)
print(confusion_matrix(y_train, y_train_predict))
print(classification_report(y_train, y_train_predict))
# Out:
# The ADB Model Score for Train Data is:  0.8350515463917526
# [[217 115]
#  [ 61 674]]
#               precision    recall  f1-score   support
#
#          0.0       0.78      0.65      0.71       332
#          1.0       0.85      0.92      0.88       735
#
#     accuracy                           0.84      1067
#    macro avg       0.82      0.79      0.80      1067
# weighted avg       0.83      0.84      0.83      1067

# %%
sns.heatmap(confusion_matrix(y_train, y_train_predict), cmap = mycolors, annot = True, fmt="d")
# Out:
# <AxesSubplot:>

# %%
probs = ADB_model.predict_proba(x_train)
probs = probs[:, 1]
from sklearn.metrics import roc_auc_score
auc = roc_auc_score(y_train, probs)
print('AUC: %.3f' % auc)
from sklearn.metrics import roc_curve
fpr, tpr, thresholds = roc_curve(y_train, probs)
plt.plot([0, 1], [0, 1], linestyle='solid')
plt.plot(fpr, tpr, marker='.')
# Out:
# AUC: 0.902

# %%
y_test_predict = ADB_model.predict(x_test)
model_score = ADB_model.score(x_test, y_test)
print('The ADB Model Score for Train Data is: ',model_score)
print( confusion_matrix(y_test, y_test_predict))
print( classification_report(y_test, y_test_predict))
# Out:
# The ADB Model Score for Train Data is:  0.8318777292576419
# [[ 85  45]
#  [ 32 296]]
#               precision    recall  f1-score   support
#
#          0.0       0.73      0.65      0.69       130
#          1.0       0.87      0.90      0.88       328
#
#     accuracy                           0.83       458
#    macro avg       0.80      0.78      0.79       458
# weighted avg       0.83      0.83      0.83       458

# %%
sns.heatmap(confusion_matrix(y_test, y_test_predict), cmap = mycolors, annot = True, fmt="d")
# Out:
# <AxesSubplot:>

# %%
probs = ADB_model.predict_proba(x_test)
probs = probs[:, 1]
from sklearn.metrics import roc_auc_score
auc = roc_auc_score(y_test, probs)
print('AUC: %.3f' % auc)
from sklearn.metrics import roc_curve
fpr, tpr, thresholds = roc_curve(y_test, probs)
plt.plot([0, 1], [0, 1], linestyle='solid')
plt.plot(fpr, tpr, marker='.')
plt.show()
# Out:
# AUC: 0.893

# %%
#decision tree

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
param_grid = {
    'min_samples_split' : [30,50,70,100],
    'min_samples_leaf':[15,25,35,50],
    'max_depth':[5,10,15,20],
    'random_state' : [0]
}

# %%
DT_model= DecisionTreeClassifier()

# %%
grid_search=GridSearchCV(estimator=DT_model,param_grid=param_grid,cv=10)

# %%
grid_search.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=10, estimator=DecisionTreeClassifier(),
#              param_grid={'max_depth': [5, 10, 15, 20],
#                          'min_samples_leaf': [15, 25, 35, 50],
#                          'min_samples_split': [30, 50, 70, 100],
#                          'random_state': [0]})

# %%
DT_model=grid_search.best_estimator_

# %%
DT_model.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=5, min_samples_leaf=15, min_samples_split=70,
#                        random_state=0)

# %%
y_train_predict = DT_model.predict(x_train)
model_score = DT_model.score(x_train, y_train)
print(model_score)
print( confusion_matrix(y_train, y_train_predict))
print( classification_report(y_train, y_train_predict))
# Out:
# 0.837863167760075
# [[231 101]
#  [ 72 663]]
#               precision    recall  f1-score   support
#
#          0.0       0.76      0.70      0.73       332
#          1.0       0.87      0.90      0.88       735
#
#     accuracy                           0.84      1067
#    macro avg       0.82      0.80      0.81      1067
# weighted avg       0.83      0.84      0.84      1067

# %%
sns.heatmap(confusion_matrix(y_train, y_train_predict),cmap = mycolors, annot = True, fmt="d")
# Out:
# <AxesSubplot:>

# %%
probs = DT_model.predict_proba(x_train)
probs = probs[:, 1]
from sklearn.metrics import roc_auc_score
auc = roc_auc_score(y_train, probs)
print('AUC: %.3f' % auc)
from sklearn.metrics import roc_curve
fpr, tpr, thresholds = roc_curve(y_train, probs)
plt.plot([0, 1], [0, 1], linestyle='solid')
plt.plot(fpr, tpr, marker='.')
# Out:
# AUC: 0.896

# %%
y_test_predict = DT_model.predict(x_test)
model_score = DT_model.score(x_test, y_test)
print(model_score)
print( confusion_matrix(y_test, y_test_predict))
print( classification_report(y_test, y_test_predict))
# Out:
# 0.8144104803493449
# [[ 88  42]
#  [ 43 285]]
#               precision    recall  f1-score   support
#
#          0.0       0.67      0.68      0.67       130
#          1.0       0.87      0.87      0.87       328
#
#     accuracy                           0.81       458
#    macro avg       0.77      0.77      0.77       458
# weighted avg       0.81      0.81      0.81       458

# %%
sns.heatmap(confusion_matrix(y_test, y_test_predict), cmap = mycolors, annot = True, fmt="d")
# Out:
# <AxesSubplot:>

# %%
probs = DT_model.predict_proba(x_test)
probs = probs[:, 1]
from sklearn.metrics import roc_auc_score
auc = roc_auc_score(y_test, probs)
print('AUC: %.3f' % auc)
from sklearn.metrics import roc_curve
fpr, tpr, thresholds = roc_curve(y_test, probs)
plt.plot([0, 1], [0, 1], linestyle='solid')
plt.plot(fpr, tpr, marker='.')
plt.show()
# Out:
# AUC: 0.870

# %%
#Random forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
param_grid = {
    'min_samples_split' : [30,50,70,100],
    'min_samples_leaf':[15,25,35,50],
    'max_depth':[5,10,15,20],
    'random_state' : [0]
}

# %%
RF_model=RandomForestClassifier()

# %%
grid_search=GridSearchCV(estimator=RF_model,param_grid=param_grid,cv=10)

# %%
grid_search.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=10, estimator=RandomForestClassifier(),
#              param_grid={'max_depth': [5, 10, 15, 20],
#                          'min_samples_leaf': [15, 25, 35, 50],
#                          'min_samples_split': [30, 50, 70, 100],
#                          'random_state': [0]})

# %%
grid_search.best_estimator_
# Out:
# RandomForestClassifier(max_depth=10, min_samples_leaf=25, min_samples_split=30,
#                        random_state=0)

# %%
RF_model=grid_search.best_estimator_

# %%
RF_model.fit(x_train, y_train)
# Out:
# RandomForestClassifier(max_depth=10, min_samples_leaf=25, min_samples_split=30,
#                        random_state=0)

# %%
y_train_predict = RF_model.predict(x_train)
model_score =RF_model.score(x_train, y_train)
print(model_score)
print( confusion_matrix(y_train, y_train_predict))
print( classification_report(y_train, y_train_predict))
# Out:
# 0.8388003748828491
# [[208 124]
#  [ 48 687]]
#               precision    recall  f1-score   support
#
#          0.0       0.81      0.63      0.71       332
#          1.0       0.85      0.93      0.89       735
#
#     accuracy                           0.84      1067
#    macro avg       0.83      0.78      0.80      1067
# weighted avg       0.84      0.84      0.83      1067

# %%
sns.heatmap(confusion_matrix(y_train, y_train_predict), cmap = mycolors, annot = True, fmt="d")
# Out:
# <AxesSubplot:>

# %%
probs = RF_model.predict_proba(x_train)
probs = probs[:, 1]
from sklearn.metrics import roc_auc_score
auc = roc_auc_score(y_train, probs)
print('AUC: %.3f' % auc)
from sklearn.metrics import roc_curve
fpr, tpr, thresholds = roc_curve(y_train, probs)
plt.plot([0, 1], [0, 1], linestyle='solid')
plt.plot(fpr, tpr, marker='.')
# Out:
# AUC: 0.906

# %%
y_test_predict = RF_model.predict(x_test)
model_score = RF_model.score(x_test, y_test)
print(model_score)
print( confusion_matrix(y_test, y_test_predict))
print( classification_report(y_test, y_test_predict))
# Out:
# 0.834061135371179
# [[ 82  48]
#  [ 28 300]]
#               precision    recall  f1-score   support
#
#          0.0       0.75      0.63      0.68       130
#          1.0       0.86      0.91      0.89       328
#
#     accuracy                           0.83       458
#    macro avg       0.80      0.77      0.79       458
# weighted avg       0.83      0.83      0.83       458

# %%
sns.heatmap(confusion_matrix(y_test, y_test_predict), cmap = mycolors, annot = True, fmt="d")
# Out:
# <AxesSubplot:>

# %%
probs = RF_model.predict_proba(x_test)
probs = probs[:, 1]
from sklearn.metrics import roc_auc_score
auc = roc_auc_score(y_test, probs)
print('AUC: %.3f' % auc)
from sklearn.metrics import roc_curve
fpr, tpr, thresholds = roc_curve(y_test, probs)
plt.plot([0, 1], [0, 1], linestyle='solid')
plt.plot(fpr, tpr, marker='.')
plt.show()
# Out:
# AUC: 0.895
